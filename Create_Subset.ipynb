# %% [markdown]
# # Segmentation methodology for Chameleon

# %%
import numpy as np
from tqdm.auto import tqdm

#from CNN.train import train 
#from inference_pipeline.sliding_window_classification import getModule, classifyTrace, saveClassification
#from inference_pipeline.segmentation import *
#from CNN.build_dataset_chameleon import createSubsets
from CNN.my_build_dataset import createSubsets, debug_createSubsets
#from inference_pipeline.debug import *
from matplotlib import pyplot as plt
#from inference_pipeline.heuristic import removeFalseNegatives, removeFalsePositives, removeFalsePositives_basic
# Out:
# /home/megauser/.cwvenv/lib/python3.12/site-packages/lightning_fabric/__init__.py:41: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %% [markdown]
# ## CNN dataset creation

# %%
chameleon_path = "traces/RD/RD/"
dataset_out_path = "traces/RD/RD_out"

# %%
debug_createSubsets(chameleon_path, dataset_out_path)
# Out:
# ['traces/RD/RD/chameleon_rd_chunk_1.h5', 'traces/RD/RD/chameleon_rd_chunk_10.h5', 'traces/RD/RD/chameleon_rd_chunk_11.h5', 'traces/RD/RD/chameleon_rd_chunk_12.h5', 'traces/RD/RD/chameleon_rd_chunk_13.h5', 'traces/RD/RD/chameleon_rd_chunk_14.h5', 'traces/RD/RD/chameleon_rd_chunk_15.h5', 'traces/RD/RD/chameleon_rd_chunk_16.h5', 'traces/RD/RD/chameleon_rd_chunk_2.h5', 'traces/RD/RD/chameleon_rd_chunk_3.h5', 'traces/RD/RD/chameleon_rd_chunk_4.h5', 'traces/RD/RD/chameleon_rd_chunk_5.h5', 'traces/RD/RD/chameleon_rd_chunk_6.h5', 'traces/RD/RD/chameleon_rd_chunk_7.h5', 'traces/RD/RD/chameleon_rd_chunk_8.h5']
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 debug_createSubsets(chameleon_path, dataset_out_path)
#
# File ~/chameleon/CNN/my_build_dataset.py:354, in debug_createSubsets(dataset_dir, out_data_dir, window_size, split_traces)
#     352 # -------------------------------------------
#     353 dataLoader = _dataLoader(traces_files)
# --> 354 min_len = min(len(trace) for trace in all_traces)
#     355 print(min_len)
#     356 for all_traces, sample_labels, crypto_k_labels, crypto_pt_labels in tqdm(dataLoader, total=len(traces_files*16), desc="Creating dataset"):
#     357     # Cut traces --------------------------------------------------------------------------------------------
#     358     # Cut idling parts from traces
#
# UnboundLocalError: cannot access local variable 'all_traces' where it is not associated with a value
